# %%
# %pip install PyPDF2

import PyPDF2
import os
from tkinter.filedialog import askdirectory

caminho = askdirectory(title="Seleceione uma pasta")

merger = PyPDF2.PdfMerger()
lista_arquivos = os.listdir(caminho)
lista_arquivos.sort()

for arquivo in lista_arquivos:
    if ".pdf" in arquivo:
        merger.append(f"{caminho}/{arquivo}")

merger.write(f"{caminho}/PDF_FINAL.pdf")
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: PyPDF2 in c:\users\oggi\appdata\local\programs\python\python312\lib\site-packages (3.0.1)
# Note: you may need to restart the kernel to use updated packages.
