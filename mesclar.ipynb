# %%
# %pip install PyPDF2

import PyPDF2
import os
from tkinter.filedialog import askdirectory

caminho = askdirectory(title="Seleceione uma pasta")

merger = PyPDF2.PdfMerger()
lista_arquivos = os.listdir(caminho)
lista_arquivos.sort()

for arquivo in lista_arquivos:
    if ".pdf" in arquivo:
        merger.append(f"{caminho}/{arquivo}")

merger.write(f"{caminho}/PDF_FINAL.pdf")
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\oggi\desktop\estudos\programação\mesclar-pdf\.venv\lib\site-packages (3.0.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
